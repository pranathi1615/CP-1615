# %% [markdown]
# <a href="https://colab.research.google.com/github/pranathi1615/CP-1615/blob/main/week(1_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def maxMeetings(meetings):
    meetings.sort(key=lambda x: x[1])

    count = 1
    last_end = meetings[0][1]

    for i in range(1, len(meetings)):
        if meetings[i][0] >= last_end:
            count += 1
            last_end = meetings[i][1]

    return count


T = int(input())
for _ in range(T):
    N = int(input())
    meetings = []
    for _ in range(N):
        s, e = map(int, input().split())
        meetings.append((s, e))

    print(maxMeetings(meetings))
# Out:
# 1
# 3
# 1 3
# 2 4
# 4 5
# 2
