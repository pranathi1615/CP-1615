# %% [markdown]
# <a href="https://colab.research.google.com/github/Manusree1324/competitiveProgrammming/blob/main/CP_Ass_2_3(dp).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 0/1 Knapsack Problem using Dynamic Programming

n, W = map(int, input().split())

value = []
weight = []

for _ in range(n):
    v, w = map(int, input().split())
    value.append(v)
    weight.append(w)

# DP table
dp = [[0] * (W + 1) for _ in range(n + 1)]

for i in range(1, n + 1):
    for w in range(1, W + 1):
        if weight[i - 1] <= w:
            dp[i][w] = max(
                value[i - 1] + dp[i - 1][w - weight[i - 1]],
                dp[i - 1][w]
            )
        else:
            dp[i][w] = dp[i - 1][w]

print(dp[n][W])
# Out:
# 3 50
# 60 10
# 100 20
# 120 30
# 220

# %%
# Coin Change - Minimum Coins (Dynamic Programming)

n = int(input())
coins = list(map(int, input().split()))
amount = int(input())

# Initialize DP array
# dp[i] = minimum coins needed to make amount i
dp = [float('inf')] * (amount + 1)
dp[0] = 0  # 0 coins needed to make amount 0

for coin in coins:
    for i in range(coin, amount + 1):
        dp[i] = min(dp[i], dp[i - coin] + 1)

# If amount cannot be formed, print -1
if dp[amount] == float('inf'):
    print(-1)
else:
    print(dp[amount])
# Out:
# 3
# 1 3 4
# 6
# 2

# %%
# Fibonacci using Memoization (Dynamic Programming)

def fibonacci(n, memo):
    if n in memo:
        return memo[n]

    memo[n] = fibonacci(n - 1, memo) + fibonacci(n - 2, memo)
    return memo[n]

n = int(input())

memo = {0: 0, 1: 1}

print(fibonacci(n, memo))
# Out:
# 10
# 55
